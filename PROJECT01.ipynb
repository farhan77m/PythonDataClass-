# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
df.head(20)
# Out:
#    School DBN                     School Name School Level  \
# 0      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3      01M140          P.S. 140 Nathan Straus          K-8
# 4      01M140          P.S. 140 Nathan Straus          K-8
# 5      01M140          P.S. 140 Nathan Straus          K-8
# 6      01M140          P.S. 140 Nathan Straus          K-8
# 7      01M140          P.S. 140 Nathan Straus          K-8
# 8      01M184            P.S. 184m Shuang Wen          K-8
# 9      01M184            P.S. 184m Shuang Wen          K-8
# 10     01M184            P.S. 184m Shuang Wen          K-8
# 11     01M184            P.S. 184m Shuang Wen          K-8
# 12     01M188      P.S. 188 The Island School          K-8
# 13     01M188      P.S. 188 The Island School          K-8
# 14     01M188      P.S. 188 The Island School          K-8
# ...

# %%
df.tail(10)
# Out:
#        School DBN           School Name School Level  \
# 212321     84X717  Icahn Charter School          K-8
# 212322     84X717  Icahn Charter School          K-8
# 212323     84X717  Icahn Charter School          K-8
# 212324     84X717  Icahn Charter School          K-8
# 212325     84X717  Icahn Charter School          K-8
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 212321          Common Core Algebra  2016             6       87.2
# 212322          Common Core Algebra  2017             6         87
# 212323          Common Core Algebra  2017             6       88.3
# 212324           Living Environment  2015             8       76.5
# ...

# %%
df.count()
# Out:
# School DBN                     212331
# School Name                    212331
# School Level                   212331
# Regents Exam                   212321
# Year                           212331
# Total Tested                   212331
# Mean Score                     212331
# Number Scoring Below 65        212331
# Percent Scoring Below 65       212331
# Number Scoring 65 or Above     212331
# Percent Scoring 65 or Above    212331
# Number Scoring 80 or Above     212331
# Percent Scoring 80 or Above    212331
# Number Scoring CR              212331
# Percent Scoring CR             212331
# dtype: int64

# %%
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
df.isnull()
# Out:
#         School DBN  School Name  School Level  Regents Exam   Year  \
# 0            False        False         False         False  False
# 1            False        False         False         False  False
# 2            False        False         False         False  False
# 3            False        False         False         False  False
# 4            False        False         False         False  False
# ...            ...          ...           ...           ...    ...
# 212326       False        False         False         False  False
# 212327       False        False         False         False  False
# 212328       False        False         False         False  False
# 212329       False        False         False         False  False
# 212330       False        False         False         False  False
#
#         Total Tested  Mean Score  Number Scoring Below 65  \
# 0              False       False                    False
# ...

# %%
df.isnull().sum()
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %%
df.notnull()
# Out:
#         School DBN  School Name  School Level  Regents Exam  Year  \
# 0             True         True          True          True  True
# 1             True         True          True          True  True
# 2             True         True          True          True  True
# 3             True         True          True          True  True
# 4             True         True          True          True  True
# ...            ...          ...           ...           ...   ...
# 212326        True         True          True          True  True
# 212327        True         True          True          True  True
# 212328        True         True          True          True  True
# 212329        True         True          True          True  True
# 212330        True         True          True          True  True
#
#         Total Tested  Mean Score  Number Scoring Below 65  \
# 0               True        True                     True
# ...

# %%
df.notnull().sum()
# Out:
# School DBN                     212331
# School Name                    212331
# School Level                   212331
# Regents Exam                   212321
# Year                           212331
# Total Tested                   212331
# Mean Score                     212331
# Number Scoring Below 65        212331
# Percent Scoring Below 65       212331
# Number Scoring 65 or Above     212331
# Percent Scoring 65 or Above    212331
# Number Scoring 80 or Above     212331
# Percent Scoring 80 or Above    212331
# Number Scoring CR              212331
# Percent Scoring CR             212331
# dtype: int64

# %%
df.replace('s', '<5')
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4         <5
# 1                Living Environment  2015            16       77.9
# ...

# %%
df1st=df[df['School Name'] == 'P.S. 184m Shuang Wen']
print(df1st)
# Out:
#        School DBN           School Name School Level         Regents Exam  \
# 8          01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 9          01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 10         01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 11         01M184  P.S. 184m Shuang Wen          K-8   Living Environment
# 19489      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19490      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19491      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19492      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19493      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19494      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19495      01M184  P.S. 184m Shuang Wen          K-8   Living Environment
# 54250      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# ...

# %%
df2nd=df1st[['Regents Exam','Percent Scoring 65 or Above']]
print(df2nd)
# Out:
#                Regents Exam Percent Scoring 65 or Above
# 8       Common Core Algebra                          98
# 9       Common Core Algebra                        82.4
# 10      Common Core Algebra                         100
# 11       Living Environment                        98.2
# 19489   Common Core Algebra                           s
# 19490   Common Core Algebra                           s
# 19491   Common Core Algebra                           s
# 19492   Common Core Algebra                           s
# 19493   Common Core Algebra                           s
# 19494   Common Core Algebra                           s
# 19495    Living Environment                        98.2
# 54250   Common Core Algebra                           s
# 54251   Common Core Algebra                        97.2
# 54252   Common Core Algebra                           s
# 54253   Common Core Algebra                           s
# 54254   Common Core Algebra                          80
# ...

# %%
df3rd=df2nd[df2nd['Regents Exam'] == 'Common Core Algebra'] 
print(df3rd)
# Out:
#                Regents Exam Percent Scoring 65 or Above
# 8       Common Core Algebra                          98
# 9       Common Core Algebra                        82.4
# 10      Common Core Algebra                         100
# 19489   Common Core Algebra                           s
# 19490   Common Core Algebra                           s
# 19491   Common Core Algebra                           s
# 19492   Common Core Algebra                           s
# 19493   Common Core Algebra                           s
# 19494   Common Core Algebra                           s
# 54250   Common Core Algebra                           s
# 54251   Common Core Algebra                        97.2
# 54252   Common Core Algebra                           s
# 54253   Common Core Algebra                           s
# 54254   Common Core Algebra                          80
# 54255   Common Core Algebra                           s
# 54256   Common Core Algebra                           s
# ...

# %%
df4th=df[df['School Name'] == 'P.S. 188 The Island School']
print(df4th)
# Out:
#        School DBN                 School Name School Level  \
# 12         01M188  P.S. 188 The Island School          K-8
# 13         01M188  P.S. 188 The Island School          K-8
# 14         01M188  P.S. 188 The Island School          K-8
# 15         01M188  P.S. 188 The Island School          K-8
# 16         01M188  P.S. 188 The Island School          K-8
# 17         01M188  P.S. 188 The Island School          K-8
# 18811      01M188  P.S. 188 The Island School          K-8
# 19436      01M188  P.S. 188 The Island School          K-8
# 19496      01M188  P.S. 188 The Island School          K-8
# 19497      01M188  P.S. 188 The Island School          K-8
# 19498      01M188  P.S. 188 The Island School          K-8
# 19499      01M188  P.S. 188 The Island School          K-8
# 19500      01M188  P.S. 188 The Island School          K-8
# 19501      01M188  P.S. 188 The Island School          K-8
# 19502      01M188  P.S. 188 The Island School          K-8
# ...

# %%
df5th=df4th[['Regents Exam','Percent Scoring 65 or Above']]
print(df5th)
# Out:
#                Regents Exam Percent Scoring 65 or Above
# 12      Common Core Algebra                        39.1
# 13      Common Core Algebra                        72.7
# 14      Common Core Algebra                          65
# 15      Common Core English                           s
# 16       Living Environment                        47.1
# 17       Living Environment                           s
# 18811   Common Core Algebra                           s
# 19436   Common Core Algebra                           s
# 19496   Common Core Algebra                           s
# 19497   Common Core Algebra                           s
# 19498   Common Core Algebra                           s
# 19499   Common Core Algebra                           s
# 19500   Common Core English                           s
# 19501    Living Environment                           s
# 19502    Living Environment                           s
# 19503    Living Environment                           s
# ...

# %%
df6th=df5th[df5th['Regents Exam'] == 'Common Core Algebra'] 
print(df6th)
# Out:
#                Regents Exam Percent Scoring 65 or Above
# 12      Common Core Algebra                        39.1
# 13      Common Core Algebra                        72.7
# 14      Common Core Algebra                          65
# 18811   Common Core Algebra                           s
# 19436   Common Core Algebra                           s
# 19496   Common Core Algebra                           s
# 19497   Common Core Algebra                           s
# 19498   Common Core Algebra                           s
# 19499   Common Core Algebra                           s
# 54261   Common Core Algebra                           s
# 54262   Common Core Algebra                        38.9
# 54263   Common Core Algebra                           s
# 54264   Common Core Algebra                           s
# 54265   Common Core Algebra                        72.2
# 54266   Common Core Algebra                           s
# 54267   Common Core Algebra                           s
# ...
